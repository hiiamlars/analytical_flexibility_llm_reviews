# %% [markdown]
# <a href="https://colab.research.google.com/github/hiiamlars/master_thesis/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this file LLM-based or human-based reviews are preprocessed from the GEM-raw to the GEM metric such that semantics, syntax and langauge style are standardized. For this GPT-4o (gpt-4o-2024-05-13) is used.
